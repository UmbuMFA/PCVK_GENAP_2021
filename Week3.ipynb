# %% [markdown]
# <a href="https://colab.research.google.com/github/UmbuMFA/PCVK_GENAP_2021/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

print('Mengubah Tingkat Kecerahan Citra')
print('________________________________')

try:
  brightness = int(input('masukkan nilai kecerahan [-255 - 255]'))
except ValueError:
    print('Error, not a number')

try:
  a = float(input('masukkan kontras [1.0 - 3.0 ] :'))
except ValueError:
    print('Error, not a number')
  
img = cv.imread('/content/drive/MyDrive/Images/female.tiff')
brightness_image = np.zeros(img.shape , img.dtype)

#akses per piksel
for y in range(img.shape[0]):
  for x in range(img.shape[1]):
    for c in range(img.shape[2]):
      brightness_image[y,x,c] = np.clip(a * img[y,x,c] + brightness,0,255)

#cara simple tanpa for loop
#brightness_image = cv.convertScaleAbs(img, beta=brightness)

final_frame = cv.hconcat((img, brightness_image))
cv2_imshow(final_frame)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Mengubah Tingkat Kecerahan Citra
# ________________________________
# masukkan nilai kecerahan [-255 - 255]60
# masukkan kontras [1.0 - 3.0 ] :1.5
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FB113F36F10>

# %%
img = cv.imread('/content/drive/MyDrive/Images/female.tiff')
brightness_image = np.zeros(img.shape , img.dtype)

# %%
# Read an image
image = cv.imread('/content/drive/MyDrive/Images/female.tiff')


print('Mengubah Tingkat Kecerahan Citra')
print('________________________________')

try:
  r = int(input('masukkan nilai kecerahan : '))
except ValueError:
    print('Error, not a number')

# Apply log transformation method
c = 255 / np.log(1 + r )
log_image = c * (np.log(image + 1))

cv2_imshow(image)
cv2_imshow(log_image)
# Out:
# Mengubah Tingkat Kecerahan Citra
# ________________________________
# masukkan nilai kecerahan : 40
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FB113900A90>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FB11611AED0>
